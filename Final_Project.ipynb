# %% [markdown]
# #  Project

# %%
# project problem statement
# Assume your are teacher of the class
# write a program to :
#  1. Read the student names and students total marks of your class of atleast 3 or more students
# 2. rank the top3 students of your class.
# 3. provide a cash rewars of $500 to the student who secures first rank. $ 300 for second rank and $100 for the third rank.
      # the values of cash rewarded cannot be modified
# 4. make a statement of apprection to the students who secured 950 marks and above

# %%
import operator
def readStudentDetails():
    print("Enter the number of students ")
    numberOfStudents = int(input())
    studentRecord = {}  # is used to store the name and marks of the students generated by for loop
    for student in range(0,numberOfStudents):
        print(" Enter the Name of the student :  ")
        name = input()
        print("Enter the total Marks of the student:  ")
        marks = int(input())
        studentRecord[name] = marks # name is key and marks are values to the dictioanry.
    return studentRecord # dictionary is accessed inside the function only , in order to access outside use the keyword return.
def rankStudents(studentRecord):  # dictionaries are unordered collections
 sortedStudentRecord = sorted(studentRecord.items(), key= operator.itemgetter(1)) # this will convert dictionary into list of tuples
 print(sortedStudentRecord)
def rewardsStudents(): 
    pass
def appreciateStudent():
    pass
studentRecord = readStudentDetails()
rankStudents(studentRecord)
# Out:
# Enter the number of students
# 3
#  Enter the Name of the student :
# ravi
# Enter the total Marks of the student:
# 678
#  Enter the Name of the student :
# sankar
# Enter the total Marks of the student:
# 890
#  Enter the Name of the student :
# sunil
# Enter the total Marks of the student:
# 990
# [('ravi', 678), ('sankar', 890), ('sunil', 990)]

# %%
import operator
def readStudentDetails():
    print("Enter the number of students ")
    numberOfStudents = int(input())
    studentRecord = {}  # is used to store the name and marks of the students generated by for loop
    for student in range(0,numberOfStudents):
        print(" Enter the Name of the student :  ")
        name = input()
        print("Enter the total Marks of the student:  ")
        marks = int(input())
        studentRecord[name] = marks # name is key and marks are values to the dictioanry.
    return studentRecord # dictionary is accessed inside the function only , in order to access outside use the keyword return.
def rankStudents(studentRecord):  # dictionaries are unordered collections
 sortedStudentRecord = sorted(studentRecord.items(), key= operator.itemgetter(1), reverse = True) # this will convert dictionary into list of tuples
 print(sortedStudentRecord)
def rewardsStudents(): 
    pass
def appreciateStudent():
    pass
studentRecord = readStudentDetails()
rankStudents(studentRecord)
# Out:
# Enter the number of students
# 3
#  Enter the Name of the student :
# ravi
# Enter the total Marks of the student:
# 780
#  Enter the Name of the student :
# sankar
# Enter the total Marks of the student:
# 990
#  Enter the Name of the student :
# sunil
# Enter the total Marks of the student:
# 890
# [('sankar', 990), ('sunil', 890), ('ravi', 780)]

# %%
import operator
def readStudentDetails():
    print("Enter the number of students ")
    numberOfStudents = int(input())
    studentRecord = {}  # is used to store the name and marks of the students generated by for loop
    for student in range(0,numberOfStudents):
        print(" Enter the Name of the student :  ")
        name = input()
        print("Enter the total Marks of the student:  ")
        marks = int(input())
        studentRecord[name] = marks # name is key and marks are values to the dictioanry.
    return studentRecord # dictionary is accessed inside the function only , in order to access outside use the keyword return.
def rankStudents(studentRecord):  # dictionaries are unordered collections
 sortedStudentRecord = sorted(studentRecord.items(), key= operator.itemgetter(1), reverse = True) # this will convert dictionary into list of tuples
 print(sortedStudentRecord)
 print(" {} has secured  First rank , scoring {} marks ".format(sortedStudentRecord[0][0],sortedStudentRecord[0][1])) # [0] for first record  and [0] for key
 print(" {} has secured  Second rank , scoring {} marks ".format(sortedStudentRecord[1][0],sortedStudentRecord[1][1]))
 print(" {} has secured  Third rank , scoring {} marks ".format(sortedStudentRecord[2][0],sortedStudentRecord[2][1]))
def rewardsStudents():  
    pass
def appreciateStudent():
    pass
studentRecord = readStudentDetails()
rankStudents(studentRecord)
# Out:
# Enter the number of students
# 3
#  Enter the Name of the student :
# ravi
# Enter the total Marks of the student:
# 890
#  Enter the Name of the student :
# sankar
# Enter the total Marks of the student:
# 990
#  Enter the Name of the student :
# sunil
# Enter the total Marks of the student:
# 950
# [('sankar', 990), ('sunil', 950), ('ravi', 890)]
#  sankar has secured first rank , scoring 990 marks
#  sunil has secured second rank , scoring 950 marks
#  ravi has secured third rank , scoring 890 marks

# %%
import operator
def readStudentDetails():
    print()
    print("Enter the number of students ")
    numberOfStudents = int(input())
    studentRecord = {}  # is used to store the name and marks of the students generated by for loop
    for student in range(0,numberOfStudents):
        print(" Enter the Name of the student :  ")
        name = input()
        print("Enter the total Marks of the student:  ")
        marks = int(input())
        studentRecord[name] = marks # name is key and marks are values to the dictioanry.
    print()
    return studentRecord # dictionary is accessed inside the function only , in order to access outside use the keyword return.

def rankStudents(studentRecord):  # dictionaries are unordered collections
     print()
     sortedStudentRecord = sorted(studentRecord.items(), key= operator.itemgetter(1), reverse = True) # this will convert dictionary into list of tuples
     print(sortedStudentRecord)
     print("{} has secured First rank, scoring {} marks".format(sortedStudentRecord[0][0],sortedStudentRecord[0][1])) # [0] for first record  and [0] for key
     print("{} has secured Second rank, scoring {} marks".format(sortedStudentRecord[1][0],sortedStudentRecord[1][1]))
     print("{} has secured Third rank, scoring {} marks".format(sortedStudentRecord[2][0],sortedStudentRecord[2][1]))
     print()
     return sortedStudentRecord

def rewardsStudents(sortedStudentRecord, reward):  
    print()
    print("{} Student has received a cash reward of ${}".format(sortedStudentRecord[0][0], reward[0]))
    print("{} Student has received a cash reward of ${}".format(sortedStudentRecord[1][0], reward[1]))
    print("{} Student has received a cash reward of ${}".format(sortedStudentRecord[2][0], reward[2]))
    print()
def appreciateStudent(sortedStudentRecord):
    print()
    for record in sortedStudentRecord :
          if record[1] >= 950:
            print("Congraulation on scoring {} marks, {}".format(record[1], record[0]))
          else:
            break
    print()
studentRecord = readStudentDetails()
sortedStudentRecord = rankStudents(studentRecord)
reward = (500, 300, 100)
rewardsStudents(sortedStudentRecord, reward)
appreciateStudent(sortedStudentRecord)
# Out:
# Enter the number of students
# 5
#  Enter the Name of the student :
# ravi
# Enter the total Marks of the student:
# 780
#  Enter the Name of the student :
# sankar
# Enter the total Marks of the student:
# 990
#  Enter the Name of the student :
# sunil
# Enter the total Marks of the student:
# 980
#  Enter the Name of the student :
# manu
# Enter the total Marks of the student:
# 890
#  Enter the Name of the student :
# dev
# Enter the total Marks of the student:
# 978
#
#
# [('sankar', 990), ('sunil', 980), ('dev', 978), ('manu', 890), ('ravi', 780)]
# sankar has secured First rank, scoring 990 marks
# sunil has secured Second rank, scoring 980 marks
# dev has secured Third rank, scoring 978 marks
#
#
# sankar Student has received a cash reward of $500
# sunil Student has received a cash reward of $300
# dev Student has received a cash reward of $100
#
#
# Congraulation on scoring 990 marks, sankar
# Congraulation on scoring 980 marks, sunil
# ...

# %%
import operator
def readStudentDetails():
    print()
    print("Enter the number of students ")
    numberOfStudents = int(input())
    studentRecord = {}  # is used to store the name and marks of the students generated by for loop
    for student in range(0,numberOfStudents):
        print(" Enter the Name of the student :  ")
        name = input()
        print("Enter the total Marks of the student:  ")
        marks = int(input())
        studentRecord[name] = marks # name is key and marks are values to the dictioanry.
    print()
    return studentRecord # dictionary is accessed inside the function only , in order to access outside use the keyword return.

def rankStudents(studentRecord):  # dictionaries are unordered collections
    try:
         print()
         sortedStudentRecord = sorted(studentRecord.items(), key= operator.itemgetter(1), reverse = True) # this will convert dictionary into list of tuples
         print(sortedStudentRecord)
         print("{} has secured First rank, scoring {} marks".format(sortedStudentRecord[0][0],sortedStudentRecord[0][1])) # [0] for first record  and [0] for key
         print("{} has secured Second rank, scoring {} marks".format(sortedStudentRecord[1][0],sortedStudentRecord[1][1]))
         print("{} has secured Third rank, scoring {} marks".format(sortedStudentRecord[2][0],sortedStudentRecord[2][1]))
         print()
         return sortedStudentRecord
    except IndexError:
         print("Enter minimum of 3 Students")
         quit()

def rewardsStudents(sortedStudentRecord, reward):  
    print()
    print("{} Student has received a cash reward of ${}".format(sortedStudentRecord[0][0], reward[0]))
    print("{} Student has received a cash reward of ${}".format(sortedStudentRecord[1][0], reward[1]))
    print("{} Student has received a cash reward of ${}".format(sortedStudentRecord[2][0], reward[2]))
    print()
def appreciateStudent(sortedStudentRecord):
    print()
    for record in sortedStudentRecord :
          if record[1] >= 950:
            print("Congraulation on scoring {} marks, {}".format(record[1], record[0]))
          else:
            break
    print()
studentRecord = readStudentDetails()
sortedStudentRecord = rankStudents(studentRecord)
reward = (500, 300, 100)
rewardsStudents(sortedStudentRecord, reward)
appreciateStudent(sortedStudentRecord)
# Out:
# Enter the number of students
# 0
#
#
# []
# Enter minimum of 3 Students
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-93fecdf11e1b> in <module>()
#      45 sortedStudentRecord = rankStudents(studentRecord)
#      46 reward = (500, 300, 100)
# ---> 47 rewardsStudents(sortedStudentRecord, reward)
#      48 appreciateStudent(sortedStudentRecord)
#
# <ipython-input-1-93fecdf11e1b> in rewardsStudents(sortedStudentRecord, reward)
#      30 def rewardsStudents(sortedStudentRecord, reward):
#      31     print()
# ---> 32     print("{} Student has received a cash reward of ${}".format(sortedStudentRecord[0][0], reward[0]))
#      33     print("{} Student has received a cash reward of ${}".format(sortedStudentRecord[1][0], reward[1]))
#      34     print("{} Student has received a cash reward of ${}".format(sortedStudentRecord[2][0], reward[2]))
#
# ...

# %%
# Read the names and marks of at least 3 students
# Rank the top three students with highest marks
# Give cash rewards. $500 for first rank, $300 for second rank, $100 for third rank. Value cannot be modified
# Appreciate students who secured 950 marks and above

import operator

def readStudentDetails():
    print()
    # { 'John': 600, 'Ben': 800, 'David': 950, 'Mark': 980}
    print("Enter the number of students: ")
    numberOfStudents = int(input())
    studentRecord = {}
    for student in range(0, numberOfStudents):
        print("Enter the name of the student: ")
        name = input()
        print("Enter the marks of students: ")
        marks = int(input())
        studentRecord[name] = marks
    print()
    return studentRecord


def rankStudents(studentRecord):
    try:
        print()
        # [('Mark', 980), ('David', 950), ('Ben', 800), ('John', 600)]
        sortedStudentRecord = sorted(studentRecord.items(), key = operator.itemgetter(1), reverse = True)
        print(sortedStudentRecord)
        print("{} has secured first rank, scoring {} marks".format(sortedStudentRecord[0][0], sortedStudentRecord[0][1]))
        print("{} has secured second rank, scoring {} marks".format(sortedStudentRecord[1][0], sortedStudentRecord[1][1]))
        print("{} has secured third rank, scoring {} marks".format(sortedStudentRecord[2][0], sortedStudentRecord[2][1]))
        print()
        return sortedStudentRecord
    except IndexError:
        print("Enter a minimum of 3 students")
        quit()


def rewardStudents(sortedStudentRecord, reward):
    print()
    print("{} has received a cash reward of ${}".format(sortedStudentRecord[0][0], reward[0]))
    print("{} has received a cash reward of ${}".format(sortedStudentRecord[1][0], reward[1]))
    print("{} has received a cash reward of ${}".format(sortedStudentRecord[2][0], reward[2]))
    print()


def appreciateStudents(sortedStudentRecord):
    print()
    for record in sortedStudentRecord:
        if record[1] >= 950:
            print("Congratulations on scoring {} marks, {}".format(record[1], record[0]))
        else:
            break
    print()


studentRecord = readStudentDetails()
sortedStudentRecord = rankStudents(studentRecord)
reward = (500, 300, 100)
rewardStudents(sortedStudentRecord, reward)
appreciateStudents(sortedStudentRecord)
# Out:
# Enter the number of students:
# 0
#
#
# []
# Enter a minimum of 3 students
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-31b729dee755> in <module>()
#      59 sortedStudentRecord = rankStudents(studentRecord)
#      60 reward = (500, 300, 100)
# ---> 61 rewardStudents(sortedStudentRecord, reward)
#      62 appreciateStudents(sortedStudentRecord)
#
# <ipython-input-1-31b729dee755> in rewardStudents(sortedStudentRecord, reward)
#      40 def rewardStudents(sortedStudentRecord, reward):
#      41     print()
# ---> 42     print("{} has received a cash reward of ${}".format(sortedStudentRecord[0][0], reward[0]))
#      43     print("{} has received a cash reward of ${}".format(sortedStudentRecord[1][0], reward[1]))
#      44     print("{} has received a cash reward of ${}".format(sortedStudentRecord[2][0], reward[2]))
#
# ...
